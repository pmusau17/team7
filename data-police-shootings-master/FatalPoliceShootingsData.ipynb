# %%
import pandas as pd
import numpy as np

# %%
fps = pd.read_csv("fatal-police-shootings-data.csv")
fps.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
fps["city_state"] = fps["city"] + ", " + fps["state"]
fps
#fps["city.state"]pd.options.display.float_format = '{:,}'.format
# Out:
#         id                 name        date   manner_of_death         armed  \
# 0        3           Tim Elliot  2015-01-02              shot           gun
# 1        4     Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5   John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8      Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9    Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                  ...         ...               ...           ...
# 5987  6538          David Tovar  2021-01-21              shot  undetermined
# 5988  6543         Brian Abbott  2021-01-21              shot         knife
# 5989  6544       Steven Verdone  2021-01-22              shot         knife
# 5990  6541  Tyree Kajuan Rogers  2021-01-24              shot       vehicle
# 5991  6540         Caleb McCree  2021-01-24  shot and Tasered    box cutter
#
# ...

# %%
fps.groupby("city_state").count().sort_values(by="id", ascending=False)
# Out:
#                                   id  name  date  manner_of_death  armed  age  \
# city_state
# Los Angeles, CA                   91    85    91               91     88   84
# Phoenix, AZ                       87    81    87               87     82   82
# Houston, TX                       63    54    63               63     60   57
# Las Vegas, NV                     52    51    52               52     51   51
# San Antonio, TX                   48    45    48               48     48   43
# ...                               ..   ...   ...              ...    ...  ...
# Leavenworth, KS                    1     1     1                1      1    1
# Chase City, VA                     1     1     1                1      1    1
# Chaska, MN                         1     1     1                1      1    1
# Leadwood, MO                       1     1     1                1      1    1
# 300 block of State Line Road, TN   1     1     1                1      1    1
#
# ...
