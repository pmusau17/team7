# %%
# Import the Pandas package
import pandas as pd
import numpy as np
import re 
def clean_text(string,replace='_'):
    regex = '[^A-Za-z0-9]+'
    return re.sub(regex, replace, string)
import warnings
warnings.filterwarnings("ignore")  # Suppress all warnings

# %%
def load_files(year):
    temp_df = pd.read_excel(file_str.format(year), header = 3)
    column_list = temp_df.columns.to_list()
    if('Population' in column_list or 'population' in column_list):
        return temp_df.rename(columns = lambda col: col.lower().strip())
    else: 
        return pd.read_excel(file_str.format(year), header = 4).rename(columns = lambda col: col.lower().strip())

# %%
file_str = "data/crime_data/FBI_Crime_{}.xls"
dfs = []
for  i in range(2000,2018):
    dfs.append(load_files(i))

# %%
def clean_file_early(df):
    pass

# %%
index_to_drop = dfs[0].loc[dfs[0]['metropolitan statistical area'].isnull()].index.values[0]
list(range(index_to_drop,dfs[0].shape[0]+1))
dfs[0] = dfs[0].drop(list(range(index_to_drop,dfs[0].shape[0])),axis=0)

# %%
values = dfs[0].loc[dfs[0]['metropolitan statistical area'].str.contains(" per 100,000")].reset_index()
names = dfs[0].loc[dfs[0]['metropolitan statistical area'].str.contains("M.S.A")].reset_index()
columns = names.columns.to_list()
names.loc[:,columns[3:]] = values[columns[3:]]
names.drop(columns = ["index"],inplace=True)
names
# Out:
#                metropolitan statistical area population crime index total  \
# 0                         Abilene, TX M.S.A.     127413            4035.7
# 1                          Albany, GA M.S.A.     123424            5490.8
# 2         Albany-Schenectady-Troy, NY M.S.A.     906739            3191.2
# 3                     Albuquerque, NM M.S.A.     709724            7038.8
# 4                      Alexandria, LA M.S.A.     129586            6900.4
# 5      Allentown-Bethlehem-Easton, PA M.S.A.     633148            3021.6
# 6                         Altoona, PA M.S.A.     132942            2666.6
# 7                        Amarillo, TX M.S.A.     217100            6773.8
# 8                       Anchorage, AK M.S.A.     260900            4931.4
# 9                       Ann Arbor, MI M.S.A.     558168            3055.5
# 10                       Anniston, AL M.S.A.     118406            5610.4
# 11        Appleton-Oshkosh-Neenah, WI M.S.A.     353669            2294.2
# ...

# %%
dfs[-1][['metropolitan statistical area','counties/principal cities']] = dfs[-1][['metropolitan statistical area','counties/principal cities']].fillna('')
index_to_drop = dfs[-1][dfs[-1]['counties/principal cities'].str.contains('per 100,000')].index.values[-1]+1
dfs[-1] = dfs[-1].drop(list(range(index_to_drop,dfs[-1].shape[0])),axis=0)
print(dfs[-1][dfs[-1]['metropolitan statistical area'].str.contains('M.')].shape)
dfs[-1][dfs[-1]['counties/principal cities'].str.contains('per 100,000')].shape
# Out:
# (394, 12)
# (394, 12)

# %%
names = dfs[-1][dfs[-1]['metropolitan statistical area'].str.contains('M.')].reset_index()
values = dfs[-1][dfs[-1]['counties/principal cities'].str.contains('per 100,000')].reset_index()
columns = names.columns.to_list()[4:]
names[columns] = values[columns]

# %%
names
# Out:
#      index                      metropolitan statistical area  \
# 0        0                             Abilene, TX M.S.A.2, 3
# 1        5                                  Akron, OH M.S.A.4
# 2       11                                  Albany, GA M.S.A.
# 3       17                                 Albany, OR M.S.A.2
# 4       22                 Albany-Schenectady-Troy, NY M.S.A.
# 5       29                             Albuquerque, NM M.S.A.
# 6       34                              Alexandria, LA M.S.A.
# 7       40           Allentown-Bethlehem-Easton, PA-NJ M.S.A.
# 8       47                                 Altoona, PA M.S.A.
# 9       52                                Amarillo, TX M.S.A.
# 10      57                                    Ames, IA M.S.A.
# 11      63                               Anchorage, AK M.S.A.
# 12      68                               Ann Arbor, MI M.S.A.
# 13      73            Anniston-Oxford-Jacksonville, AL M.S.A.
# ...
